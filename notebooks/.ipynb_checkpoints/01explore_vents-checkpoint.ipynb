# %% [markdown]
# # Getting my labelled data
#
# #### Script to find:
#
# 1) all hospital admissions in which the patient was invasively ventilated in the ICU
#
# 2) in which of these admissions were patients placed back on the ventilator within 48 hours
#
# 3) remove patients that died while on the ventilator
#
# 4) look for > 2 'invasive ventilation' events in any particular hospital admission

# %% [markdown]
# #### import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### read data from the file 'proecdureevents.csv' which contains lists all invasive ventilation procedures occuring in patients in the icu

# %%
df = pd.read_csv('../data/raw/procedureevents.csv')
admits = pd.read_csv('../data/raw/admissions.csv')
#df.info()

# %% [markdown]
# #### find all 'invasive ventilation' events (identified by itemid code: 225792)

# %%
vdf= df[df['itemid']==225792]
vdf['hadm_id'].nunique()
# Out:
# 26409

# %%
vdf['hadm_id'].count()-vdf['hadm_id'].nunique()
# Out:
# 4223

# %% [markdown]
# We can see from the above table that there were 30632 ventilation events in the study, from 26409 different hospital admissions. This means that in 4223 of these admissions, the patient was ventilated multiple times.
#
# #### Get list of admissions where the patients was only ventilated once

# %%
num_ventilations = vdf['hadm_id'].value_counts()
svdf = vdf[vdf['hadm_id'].isin(num_ventilations.index[num_ventilations == 1])]
svdf
# Out:
#         subject_id   hadm_id   stay_id            starttime  \
# 25        13859862  25015072  31891587  2152-04-07 01:50:00
# 78        18917458  28038802  31692394  2185-12-15 21:11:00
# 96        19704964  21790335  30998091  2140-03-10 04:44:00
# 105       19004463  24357541  37805052  2177-01-14 02:35:00
# 212       19350792  23255460  34502665  2172-11-17 23:53:00
# ...            ...       ...       ...                  ...
# 689692    18667869  29258317  38880976  2126-07-24 23:01:00
# 689726    14798663  27815009  39028934  2113-10-25 11:35:00
# 689734    18616832  29021730  30844212  2196-04-16 12:50:00
# 689748    17304212  27385559  38342744  2154-06-29 18:29:00
# 689794    15650971  21353701  36735086  2149-10-10 22:59:00
#
#                     endtime                storetime  itemid         value  \
# 25      2152-04-10 18:57:00      2152-04-10 19:07:00  225792     89.116667
# 78      2185-12-20 09:59:00      2185-12-21 08:31:00  225792    108.800000
# 96      2140-03-11 13:44:00  2140-03-11 13:44:47.817  225792     33.000000
# 105     2177-02-10 14:00:00      2177-02-11 13:33:00  225792    659.416667
# 212     2172-11-20 08:06:00  2172-11-20 08:06:46.433  225792     56.216667
# ...                     ...                      ...     ...           ...
# 689692  2126-07-25 17:00:00      2126-07-25 17:04:00  225792   1079.000000
# 689726  2113-10-26 10:11:00      2113-10-26 10:12:00  225792   1356.000000
# 689734  2196-04-16 15:45:00      2196-04-16 15:53:00  225792    175.000000
# 689748  2154-06-29 21:52:00      2154-06-29 22:16:00  225792    203.000000
# 689794  2149-10-21 16:00:00      2149-10-21 18:01:00  225792  15421.000000
#
#        valueuom location  ... patientweight  totalamount  totalamountuom  \
# 25         hour      NaN  ...          58.0          NaN             NaN
# 78         hour      NaN  ...         104.0          NaN             NaN
# 96         hour      NaN  ...         106.0          NaN             NaN
# 105        hour      NaN  ...          76.1          NaN             NaN
# 212        hour      NaN  ...          63.0          NaN             NaN
# ...         ...      ...  ...           ...          ...             ...
# 689692      min      NaN  ...          83.5          NaN             NaN
# 689726      min      NaN  ...          85.8          NaN             NaN
# 689734      min      NaN  ...          90.6          NaN             NaN
# 689748      min      NaN  ...          65.0          NaN             NaN
# 689794      min      NaN  ...          82.3          NaN             NaN
#
#        isopenbag  continueinnextdept cancelreason  statusdescription  \
# 25             1                   0            0    FinishedRunning
# 78             1                   0            0    FinishedRunning
# 96             1                   0            0    FinishedRunning
# 105            1                   0            0    FinishedRunning
# 212            1                   0            0    FinishedRunning
# ...          ...                 ...          ...                ...
# 689692         1                   0            0    FinishedRunning
# 689726         1                   0            0    FinishedRunning
# 689734         1                   0            0    FinishedRunning
# 689748         1                   0            0    FinishedRunning
# 689794         1                   0            0    FinishedRunning
#
#         comments_date  originalamount  originalrate
# 25                NaN         89.1167             1
# 78                NaN        108.8000             1
# 96                NaN         33.0000             1
# 105               NaN        659.4170             1
# 212               NaN         56.2167             1
# ...               ...             ...           ...
# 689692            NaN       1079.0000             1
# 689726            NaN       1356.0000             1
# 689734            NaN        175.0000             1
# 689748            NaN        203.0000             1
# 689794            NaN      15421.0000             1
#
# [23311 rows x 26 columns]

# %%
svdf = svdf.assign(re_intub_class=0)
svdf
# Out:
#         subject_id   hadm_id   stay_id            starttime  \
# 25        13859862  25015072  31891587  2152-04-07 01:50:00
# 78        18917458  28038802  31692394  2185-12-15 21:11:00
# 96        19704964  21790335  30998091  2140-03-10 04:44:00
# 105       19004463  24357541  37805052  2177-01-14 02:35:00
# 212       19350792  23255460  34502665  2172-11-17 23:53:00
# ...            ...       ...       ...                  ...
# 689692    18667869  29258317  38880976  2126-07-24 23:01:00
# 689726    14798663  27815009  39028934  2113-10-25 11:35:00
# 689734    18616832  29021730  30844212  2196-04-16 12:50:00
# 689748    17304212  27385559  38342744  2154-06-29 18:29:00
# 689794    15650971  21353701  36735086  2149-10-10 22:59:00
#
#                     endtime                storetime  itemid         value  \
# 25      2152-04-10 18:57:00      2152-04-10 19:07:00  225792     89.116667
# 78      2185-12-20 09:59:00      2185-12-21 08:31:00  225792    108.800000
# 96      2140-03-11 13:44:00  2140-03-11 13:44:47.817  225792     33.000000
# 105     2177-02-10 14:00:00      2177-02-11 13:33:00  225792    659.416667
# 212     2172-11-20 08:06:00  2172-11-20 08:06:46.433  225792     56.216667
# ...                     ...                      ...     ...           ...
# 689692  2126-07-25 17:00:00      2126-07-25 17:04:00  225792   1079.000000
# 689726  2113-10-26 10:11:00      2113-10-26 10:12:00  225792   1356.000000
# 689734  2196-04-16 15:45:00      2196-04-16 15:53:00  225792    175.000000
# 689748  2154-06-29 21:52:00      2154-06-29 22:16:00  225792    203.000000
# 689794  2149-10-21 16:00:00      2149-10-21 18:01:00  225792  15421.000000
#
#        valueuom location  ... totalamount  totalamountuom  isopenbag  \
# 25         hour      NaN  ...         NaN             NaN          1
# 78         hour      NaN  ...         NaN             NaN          1
# 96         hour      NaN  ...         NaN             NaN          1
# 105        hour      NaN  ...         NaN             NaN          1
# 212        hour      NaN  ...         NaN             NaN          1
# ...         ...      ...  ...         ...             ...        ...
# 689692      min      NaN  ...         NaN             NaN          1
# 689726      min      NaN  ...         NaN             NaN          1
# 689734      min      NaN  ...         NaN             NaN          1
# 689748      min      NaN  ...         NaN             NaN          1
# 689794      min      NaN  ...         NaN             NaN          1
#
#        continueinnextdept  cancelreason statusdescription  comments_date  \
# 25                      0             0   FinishedRunning            NaN
# 78                      0             0   FinishedRunning            NaN
# 96                      0             0   FinishedRunning            NaN
# 105                     0             0   FinishedRunning            NaN
# 212                     0             0   FinishedRunning            NaN
# ...                   ...           ...               ...            ...
# 689692                  0             0   FinishedRunning            NaN
# 689726                  0             0   FinishedRunning            NaN
# 689734                  0             0   FinishedRunning            NaN
# 689748                  0             0   FinishedRunning            NaN
# 689794                  0             0   FinishedRunning            NaN
#
#         originalamount  originalrate  re_intub_class
# 25             89.1167             1               0
# 78            108.8000             1               0
# 96             33.0000             1               0
# 105           659.4170             1               0
# 212            56.2167             1               0
# ...                ...           ...             ...
# 689692       1079.0000             1               0
# 689726       1356.0000             1               0
# 689734        175.0000             1               0
# 689748        203.0000             1               0
# 689794      15421.0000             1               0
#
# [23311 rows x 27 columns]

# %% [markdown]
# #### Get list of admissions where the patients was ventilated a second time within 48 hours

# %%
mvdf = vdf[vdf['hadm_id'].isin(num_ventilations.index[num_ventilations == 2])]
sorted_mvdf = mvdf.sort_values(['hadm_id', 'starttime'], ascending=[True, True])  # sort table by hadm_id followed by starttime

sorted_mvdf['starttime'] = pd.to_datetime(sorted_mvdf['starttime']) # convert times to datetime objects
sorted_mvdf['endtime'] = pd.to_datetime(sorted_mvdf['endtime']) 

first_vent = sorted_mvdf.iloc[::2] # slice dataframe so only have first ventilation events
second_vent=sorted_mvdf.iloc[1::2] # slice dataframe so only have second ventilation events

vent_diff = pd.merge(left = first_vent,right = second_vent,on = 'hadm_id')  # merge table so start/endtimes for both ventilaton events from an admission are in the same row for 
vent_diff['timetosecondvent']= vent_diff['starttime_y'] - vent_diff['endtime_x'] # add column of time difference between end of first ventilation event and beginning of second ventilation event 
vent_diff['timetosecondvent'] = vent_diff['timetosecondvent'] / np.timedelta64(1, 'h') # convert time to hours
re_vent = vent_diff[vent_diff['timetosecondvent']<48]

# %%
re_vent.columns = ['subject_id_x', 'hadm_id', 'stay_id_x', 'starttime_x', 'endtime',
       'storetime_x', 'itemid_x', 'value', 'valueuom', 'location_x',
       'locationcategory_x', 'orderid_x', 'linkorderid_x',
       'ordercategoryname_x', 'secondaryordercategoryname_x',
       'ordercategorydescription_x', 'patientweight_x', 'totalamount_x',
       'totalamountuom_x', 'isopenbag_x', 'continueinnextdept_x',
       'cancelreason_x', 'statusdescription_x', 'comments_date_x',
       'originalamount_x', 'originalrate_x', 'subject_id_y', 'stay_id_y',
       'starttime_y', 'endtime_y', 'storetime_y', 'itemid_y', 'value_y',
       'valueuom_y', 'location_y', 'locationcategory_y', 'orderid_y',
       'linkorderid_y', 'ordercategoryname_y', 'secondaryordercategoryname_y',
       'ordercategorydescription_y', 'patientweight_y', 'totalamount_y',
       'totalamountuom_y', 'isopenbag_y', 'continueinnextdept_y',
       'cancelreason_y', 'statusdescription_y', 'comments_date_y',
       'originalamount_y', 'originalrate_y', 'timetosecondvent']

# %%
re_vent = re_vent.assign(re_intub_class=1)
re_vent
# Out:
#       subject_id_x   hadm_id  stay_id_x         starttime_x  \
# 2         17223646  20023461   36478017 2152-11-03 11:10:00
# 3         16779215  20024229   38542512 2132-08-27 16:00:00
# 4         13605251  20025172   38493547 2139-12-31 14:02:00
# 5         16976998  20034762   30778603 2164-06-07 08:10:00
# 6         15878712  20035700   30421802 2123-02-01 10:22:00
# ...            ...       ...        ...                 ...
# 2337      16691924  29960248   32296652 2146-12-06 12:55:00
# 2338      16796371  29962016   38636381 2135-10-21 09:40:00
# 2341      10020944  29974575   33972149 2131-02-27 17:00:00
# 2343      19652570  29987115   35887309 2148-02-17 14:00:00
# 2345      19181803  29995768   36883182 2178-05-16 19:00:00
#
#                  endtime              storetime_x  itemid_x    value valueuom  \
# 2    2152-11-03 16:44:00      2152-11-03 16:45:00    225792    334.0      min
# 3    2132-08-28 17:30:00      2132-08-28 17:43:00    225792   1530.0      min
# 4    2140-01-04 11:09:00      2140-01-04 11:09:00    225792   5587.0      min
# 5    2164-06-08 14:00:00      2164-06-08 17:51:00    225792   1790.0      min
# 6    2123-02-05 14:52:00      2123-02-05 18:01:00    225792   6030.0      min
# ...                  ...                      ...       ...      ...      ...
# 2337 2146-12-09 14:23:00      2146-12-09 14:25:00    225792   4408.0      min
# 2338 2135-10-30 11:45:00      2135-10-30 12:27:00    225792  13085.0      min
# 2341 2131-03-03 19:54:00      2131-03-04 09:55:00    225792   5934.0      min
# 2343 2148-02-19 10:00:00      2148-02-19 10:02:00    225792   2640.0      min
# 2345 2178-05-17 21:57:00  2178-05-17 21:57:36.597    225792   1617.0      min
#
#      location_x  ... totalamountuom_y  isopenbag_y  continueinnextdept_y  \
# 2           NaN  ...              NaN            1                     0
# 3           NaN  ...              NaN            1                     0
# 4           NaN  ...              NaN            1                     0
# 5           NaN  ...              NaN            1                     0
# 6           NaN  ...              NaN            1                     0
# ...         ...  ...              ...          ...                   ...
# 2337        NaN  ...              NaN            1                     0
# 2338        NaN  ...              NaN            1                     0
# 2341        NaN  ...              NaN            1                     0
# 2343        NaN  ...              NaN            1                     0
# 2345        NaN  ...              NaN            0                     0
#
#      cancelreason_y  statusdescription_y comments_date_y  originalamount_y  \
# 2                 0      FinishedRunning             NaN            6831.0
# 3                 0      FinishedRunning             NaN            5554.0
# 4                 0      FinishedRunning             NaN           23548.0
# 5                 0      FinishedRunning             NaN            1901.0
# 6                 0      FinishedRunning             NaN            2014.0
# ...             ...                  ...             ...               ...
# 2337              0      FinishedRunning             NaN            3136.0
# 2338              0      FinishedRunning             NaN            2842.0
# 2341              0      FinishedRunning             NaN            5446.0
# 2343              0      FinishedRunning             NaN             395.0
# 2345              0      FinishedRunning             NaN            1617.0
#
#       originalrate_y  timetosecondvent  re_intub_class
# 2                  1          0.766667               1
# 3                  1         34.716667               1
# 4                  1         21.133333               1
# 5                  1         45.183333               1
# 6                  1         34.633333               1
# ...              ...               ...             ...
# 2337               1         10.283333               1
# 2338               1          0.583333               1
# 2341               1          0.283333               1
# 2343               1         26.350000               1
# 2345               1         -0.066667               1
#
# [1368 rows x 53 columns]

# %%
sample_vents = pd.concat([svdf[['hadm_id','endtime','value','valueuom','re_intub_class']],re_vent[['hadm_id','endtime','value','valueuom','re_intub_class']]])

# %%
sample_vents
# Out:
#        hadm_id              endtime         value valueuom  re_intub_class
# 25    25015072  2152-04-10 18:57:00     89.116667     hour               0
# 78    28038802  2185-12-20 09:59:00    108.800000     hour               0
# 96    21790335  2140-03-11 13:44:00     33.000000     hour               0
# 105   24357541  2177-02-10 14:00:00    659.416667     hour               0
# 212   23255460  2172-11-20 08:06:00     56.216667     hour               0
# ...        ...                  ...           ...      ...             ...
# 2337  29960248  2146-12-09 14:23:00   4408.000000      min               1
# 2338  29962016  2135-10-30 11:45:00  13085.000000      min               1
# 2341  29974575  2131-03-03 19:54:00   5934.000000      min               1
# 2343  29987115  2148-02-19 10:00:00   2640.000000      min               1
# 2345  29995768  2178-05-17 21:57:00   1617.000000      min               1
#
# [24679 rows x 5 columns]

# %% [markdown]
# #### Join sample_vents and admissions table together

# %%
merged_inner = pd.merge(left= sample_vents, right=admits, left_on='hadm_id', right_on='hadm_id')
merged_inner
# Out:
#         hadm_id              endtime         value valueuom  re_intub_class  \
# 0      25015072  2152-04-10 18:57:00     89.116667     hour               0
# 1      28038802  2185-12-20 09:59:00    108.800000     hour               0
# 2      21790335  2140-03-11 13:44:00     33.000000     hour               0
# 3      24357541  2177-02-10 14:00:00    659.416667     hour               0
# 4      23255460  2172-11-20 08:06:00     56.216667     hour               0
# ...         ...                  ...           ...      ...             ...
# 24674  29960248  2146-12-09 14:23:00   4408.000000      min               1
# 24675  29962016  2135-10-30 11:45:00  13085.000000      min               1
# 24676  29974575  2131-03-03 19:54:00   5934.000000      min               1
# 24677  29987115  2148-02-19 10:00:00   2640.000000      min               1
# 24678  29995768  2178-05-17 21:57:00   1617.000000      min               1
#
#        subject_id            admittime            dischtime  \
# 0        13859862  2152-03-27 12:44:00  2152-04-11 03:00:00
# 1        18917458  2185-12-15 00:17:00  2185-12-22 17:15:00
# 2        19704964  2140-03-09 14:44:00  2140-03-15 13:00:00
# 3        19004463  2176-12-16 18:11:00  2177-02-15 17:00:00
# 4        19350792  2172-11-17 17:21:00  2172-11-20 06:00:00
# ...           ...                  ...                  ...
# 24674    16691924  2146-11-30 16:09:00  2146-12-17 17:04:00
# 24675    16796371  2135-10-21 08:16:00  2135-11-04 13:30:00
# 24676    10020944  2131-02-27 15:34:00  2131-03-13 17:01:00
# 24677    19652570  2148-02-16 17:42:00  2148-02-20 19:00:00
# 24678    19181803  2178-05-16 18:46:00  2178-05-17 16:15:00
#
#                  deathtime admission_type      admission_location  \
# 0      2152-04-11 03:00:00       EW EMER.          EMERGENCY ROOM
# 1                      NaN       EW EMER.          EMERGENCY ROOM
# 2                      NaN         URGENT      PHYSICIAN REFERRAL
# 3                      NaN         URGENT  TRANSFER FROM HOSPITAL
# 4      2172-11-20 06:00:00       EW EMER.          EMERGENCY ROOM
# ...                    ...            ...                     ...
# 24674                  NaN   DIRECT EMER.         CLINIC REFERRAL
# 24675                  NaN       EW EMER.          EMERGENCY ROOM
# 24676                  NaN       EW EMER.          EMERGENCY ROOM
# 24677  2148-02-20 19:00:00         URGENT  TRANSFER FROM HOSPITAL
# 24678                  NaN       EW EMER.          EMERGENCY ROOM
#
#              discharge_location insurance language marital_status  \
# 0                          DIED  Medicare  ENGLISH        WIDOWED
# 1                       HOSPICE  Medicaid  ENGLISH        MARRIED
# 2                          HOME     Other        ?        MARRIED
# 3                         REHAB  Medicare  ENGLISH        MARRIED
# 4                          DIED  Medicare        ?         SINGLE
# ...                         ...       ...      ...            ...
# 24674  SKILLED NURSING FACILITY  Medicare  ENGLISH        WIDOWED
# 24675                     REHAB  Medicare  ENGLISH         SINGLE
# 24676  SKILLED NURSING FACILITY  Medicare  ENGLISH            NaN
# 24677                      DIED     Other  ENGLISH            NaN
# 24678                      DIED     Other  ENGLISH        MARRIED
#
#                     ethnicity            edregtime            edouttime  \
# 0                       WHITE  2152-03-27 09:46:00  2152-03-27 14:17:00
# 1                       WHITE  2185-12-14 23:05:00  2185-12-15 01:31:00
# 2            UNABLE TO OBTAIN                  NaN                  NaN
# 3                       WHITE                  NaN                  NaN
# 4                       ASIAN  2172-11-17 15:05:00  2172-11-17 18:39:00
# ...                       ...                  ...                  ...
# 24674                   WHITE                  NaN                  NaN
# 24675  BLACK/AFRICAN AMERICAN  2135-10-21 05:47:00  2135-10-21 09:45:00
# 24676                 UNKNOWN  2131-02-27 13:16:00  2131-02-27 16:40:00
# 24677                 UNKNOWN                  NaN                  NaN
# 24678                   WHITE  2178-05-16 14:43:00  2178-05-16 19:42:00
#
#        hospital_expire_flag
# 0                         1
# 1                         0
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 24674                     0
# 24675                     0
# 24676                     0
# 24677                     1
# 24678                     0
#
# [24679 rows x 19 columns]

# %% [markdown]
# #### Find patients that died within 24 hours of being taken off the ventilator

# %%
merged_inner['endtime'] = pd.to_datetime(merged_inner['endtime'])  # convert to datetime object
merged_inner['deathtime'] = pd.to_datetime(merged_inner['deathtime'])
merged_inner['time_to_death']= merged_inner['endtime']-merged_inner['deathtime']  # find time difference between death and being taken off vent
merged_inner['hours_to_death'] = merged_inner['time_to_death'] / np.timedelta64(1, 'h') # convert time to hours

# %%
dead_patients = merged_inner[merged_inner['hours_to_death'].notnull()]  # find patients that died

# %%
died_on_vent = dead_patients[(dead_patients['hours_to_death']<24)&(dead_patients['hours_to_death']>-24)] # find patients that died while on the ventilator

# %%
dead_ids = died_on_vent['hadm_id'].tolist()
not_dead_vents = merged_inner[~merged_inner.hadm_id.isin(dead_ids)]

# %% [markdown]
# #### make sure time on vent is all in hours and only use data from when patients were on the vent for more than 6 hours

# %%
svents_keep = not_dead_vents.copy()

# %%
svents_keep['value'] = np.where(svents_keep['valueuom']=='min',(svents_keep['value']/60),svents_keep['value'])
svents_keep['value'] = np.where(svents_keep['valueuom']=='day',(svents_keep['value']*24),svents_keep['value'])
svents_keep.drop(['valueuom','time_to_death'],axis=1,inplace=True)
svents_keep.rename(columns = {"value":"time_on_vent"},inplace=True)

# %%
svents_keep
# Out:
#         hadm_id             endtime  time_on_vent  re_intub_class  subject_id  \
# 1      28038802 2185-12-20 09:59:00    108.800000               0    18917458
# 2      21790335 2140-03-11 13:44:00     33.000000               0    19704964
# 3      24357541 2177-02-10 14:00:00    659.416667               0    19004463
# 5      22188993 2145-11-04 18:40:00    143.666667               0    11538389
# 7      21880799 2134-05-22 17:58:00     54.966667               0    16606203
# ...         ...                 ...           ...             ...         ...
# 24674  29960248 2146-12-09 14:23:00     73.466667               1    16691924
# 24675  29962016 2135-10-30 11:45:00    218.083333               1    16796371
# 24676  29974575 2131-03-03 19:54:00     98.900000               1    10020944
# 24677  29987115 2148-02-19 10:00:00     44.000000               1    19652570
# 24678  29995768 2178-05-17 21:57:00     26.950000               1    19181803
#
#                  admittime            dischtime           deathtime  \
# 1      2185-12-15 00:17:00  2185-12-22 17:15:00                 NaT
# 2      2140-03-09 14:44:00  2140-03-15 13:00:00                 NaT
# 3      2176-12-16 18:11:00  2177-02-15 17:00:00                 NaT
# 5      2145-10-29 12:46:00  2145-11-09 17:30:00 2145-11-09 17:30:00
# 7      2134-05-20 09:51:00  2134-05-22 18:00:00                 NaT
# ...                    ...                  ...                 ...
# 24674  2146-11-30 16:09:00  2146-12-17 17:04:00                 NaT
# 24675  2135-10-21 08:16:00  2135-11-04 13:30:00                 NaT
# 24676  2131-02-27 15:34:00  2131-03-13 17:01:00                 NaT
# 24677  2148-02-16 17:42:00  2148-02-20 19:00:00 2148-02-20 19:00:00
# 24678  2178-05-16 18:46:00  2178-05-17 16:15:00                 NaT
#
#       admission_type      admission_location            discharge_location  \
# 1           EW EMER.          EMERGENCY ROOM                       HOSPICE
# 2             URGENT      PHYSICIAN REFERRAL                          HOME
# 3             URGENT  TRANSFER FROM HOSPITAL                         REHAB
# 5           EW EMER.          EMERGENCY ROOM                          DIED
# 7           EW EMER.          EMERGENCY ROOM  CHRONIC/LONG TERM ACUTE CARE
# ...              ...                     ...                           ...
# 24674   DIRECT EMER.         CLINIC REFERRAL      SKILLED NURSING FACILITY
# 24675       EW EMER.          EMERGENCY ROOM                         REHAB
# 24676       EW EMER.          EMERGENCY ROOM      SKILLED NURSING FACILITY
# 24677         URGENT  TRANSFER FROM HOSPITAL                          DIED
# 24678       EW EMER.          EMERGENCY ROOM                          DIED
#
#       insurance language marital_status               ethnicity  \
# 1      Medicaid  ENGLISH        MARRIED                   WHITE
# 2         Other        ?        MARRIED        UNABLE TO OBTAIN
# 3      Medicare  ENGLISH        MARRIED                   WHITE
# 5      Medicare  ENGLISH        MARRIED                 UNKNOWN
# 7      Medicare        ?        MARRIED         HISPANIC/LATINO
# ...         ...      ...            ...                     ...
# 24674  Medicare  ENGLISH        WIDOWED                   WHITE
# 24675  Medicare  ENGLISH         SINGLE  BLACK/AFRICAN AMERICAN
# 24676  Medicare  ENGLISH            NaN                 UNKNOWN
# 24677     Other  ENGLISH            NaN                 UNKNOWN
# 24678     Other  ENGLISH        MARRIED                   WHITE
#
#                  edregtime            edouttime  hospital_expire_flag  \
# 1      2185-12-14 23:05:00  2185-12-15 01:31:00                     0
# 2                      NaN                  NaN                     0
# 3                      NaN                  NaN                     0
# 5      2145-10-29 11:07:00  2145-10-29 14:00:00                     1
# 7      2134-05-20 06:11:00  2134-05-20 11:15:00                     0
# ...                    ...                  ...                   ...
# 24674                  NaN                  NaN                     0
# 24675  2135-10-21 05:47:00  2135-10-21 09:45:00                     0
# 24676  2131-02-27 13:16:00  2131-02-27 16:40:00                     0
# 24677                  NaN                  NaN                     1
# 24678  2178-05-16 14:43:00  2178-05-16 19:42:00                     0
#
#        hours_to_death
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 5         -118.833333
# 7                 NaN
# ...               ...
# 24674             NaN
# 24675             NaN
# 24676             NaN
# 24677      -33.000000
# 24678             NaN
#
# [21645 rows x 19 columns]

# %%
svents_keep = svents_keep[(svents_keep['time_on_vent']>6)]

# %%
svents_keep.columns
# Out:
# Index(['hadm_id', 'endtime', 'time_on_vent', 're_intub_class', 'subject_id',
#        'admittime', 'dischtime', 'deathtime', 'admission_type',
#        'admission_location', 'discharge_location', 'insurance', 'language',
#        'marital_status', 'ethnicity', 'edregtime', 'edouttime',
#        'hospital_expire_flag', 'hours_to_death'],
#       dtype='object')

# %% [markdown]
# #### save to csv

# %%
#svents_keep.to_csv('../data/processed/sample_vents.csv',index= False)
