# %% [markdown]
# ## Exploratory data analysis file pre-modelling

# %% [markdown]
# #### import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### read cleaned data frame

# %%
df = pd.read_feather('../data/processed/clean_copd')

# %%
df_features = df.copy()

# %%
df_features.drop(['hadm_id','endtime','seq_num',
                 'icd_code'],axis=1,inplace=True)

# %%
df_features
# Out:
#      time_on_vent  re_intub_class gender     admission_type  anchor_age  \
# 0      168.400000               0      M           EW EMER.          60
# 1       77.400000               0      F           EW EMER.          77
# 2       49.250000               1      M             URGENT          73
# 3       13.333333               0      F           EW EMER.          38
# 4       97.300000               0      F             URGENT          60
# ..            ...             ...    ...                ...         ...
# 752     84.916667               0      M           EW EMER.          66
# 753     26.000000               0      M           EW EMER.          62
# 754    125.016667               0      F             URGENT          77
# 755    281.300000               0      M             URGENT          69
# 756     84.700000               0      F  OBSERVATION ADMIT          71
#
#      spontrr  heartrate  std_spontrr  weight  sodium  ...  creatinine   bun  \
# 0       22.0      124.0     8.140434   140.1   133.0  ...         0.7  30.0
# 1       20.0       96.0     5.348936   132.0   149.0  ...         1.6  34.0
# 2       27.0       89.0     5.253570   154.0   134.0  ...         0.8  37.0
# 3       16.0       86.0     6.244998   162.8   141.0  ...         0.6   6.0
# 4       33.0      104.0     3.900142   158.4   141.0  ...         1.0  24.0
# ..       ...        ...          ...     ...     ...  ...         ...   ...
# 752     18.0       71.0     3.076795   274.8   150.0  ...         1.7  75.0
# 753     16.0      101.0     5.970164   221.1   133.0  ...         1.5  60.0
# 754     15.0       88.0     5.724418   152.2   144.0  ...         1.4  54.0
# 755     17.0       87.0     2.675857   149.8   144.0  ...         0.6  32.0
# 756     24.0       84.0     2.282224   268.4   144.0  ...         1.6  11.0
#
#         height  lactic_acid  hemoglobin   wbg  tidalvolume       temp  \
# 0    72.917323          1.6         8.9   5.9        461.0  36.444444
# 1    66.964567          1.5         9.7  11.2        465.0  37.111111
# 2    70.039370          2.0        10.8   0.6        533.0  35.666667
# 3    64.980315          0.7        10.8  20.3        474.0  36.666667
# 4    61.905512          1.5        10.5  17.3        387.0  38.222222
# ..         ...          ...         ...   ...          ...        ...
# 752  66.964567          1.7         9.4   8.5        407.0  36.888889
# 753  74.007874          1.7         7.7  26.4        552.0  36.944444
# 754  59.921260          1.1         8.1  15.2        357.0  38.888889
# 755  66.070866          0.5         7.6   9.9        764.0  37.000000
# 756  64.086614          0.8         7.1  15.0        475.0  37.166667
#
#      std_bloodpressure  pulseox
# 0            18.906789     98.0
# 1            12.537942     97.0
# 2            13.377308     99.0
# 3            14.729891     95.0
# 4             3.386247     97.0
# ..                 ...      ...
# 752           5.913262    100.0
# 753           2.422120     96.0
# 754           6.534524     99.0
# 755           4.956477    100.0
# 756           9.373633    100.0
#
# [757 rows x 27 columns]

# %%
from scipy.stats import shapiro, normaltest

# %%
df_continuous = df_features.copy()

# %%
df_continuous.drop(['gender','admission_type','re_intub_class'],axis=1, inplace=True)

# %%
df_continuous.apply(normaltest)
# Out:
#     time_on_vent  anchor_age    spontrr     heartrate   std_spontrr  \
# 0   5.583877e+02   10.737783  10.654826  2.904924e+01  1.514883e+02
# 1  5.593106e-122    0.004659   0.004857  4.920832e-07  1.272707e-33
#
#          weight    sodium      abg_po2       abg_ph       hco3  ...  \
# 0  1.726137e+02  3.142935  1984.035171  1984.037961  18.905900  ...
# 1  3.291655e-38  0.207740     0.000000     0.000000   0.000078  ...
#
#      creatinine           bun     height  lactic_acid    hemoglobin  \
# 0  4.533619e+02  2.371159e+02  12.807420  1984.037961  6.290512e+01
# 1  3.578537e-99  3.242976e-52   0.001655     0.000000  2.189403e-14
#
#             wbg   tidalvolume         temp  std_bloodpressure       pulseox
# 0  1.798614e+02  8.743840e+01  1904.992714       1.430956e+03  6.537756e+01
# 1  8.782186e-40  1.030368e-19     0.000000      1.869891e-311  6.359799e-15
#
# [2 rows x 24 columns]

# %%
df_continuous.apply(shapiro)
# Out:
#    time_on_vent  anchor_age   spontrr     heartrate   std_spontrr  \
# 0  6.445186e-01    0.991804  0.988166  9.809510e-01  9.204760e-01
# 1  7.281976e-37    0.000336  0.000009  2.305664e-08  1.568504e-19
#
#          weight    sodium   abg_po2   abg_ph      hco3  ...    creatinine  \
# 0  9.377437e-01  0.993980  0.015317  0.01501  0.985888  ...  7.160473e-01
# 1  3.017078e-17  0.004073  0.000000  0.00000  0.000001  ...  6.792792e-34
#
#             bun        height  lactic_acid    hemoglobin           wbg  \
# 0  8.503692e-01  9.850758e-01     0.015013  9.568901e-01  9.314685e-01
# 1  3.838937e-26  5.627128e-07     0.000000  4.166620e-14  3.998630e-18
#
#     tidalvolume      temp  std_bloodpressure       pulseox
# 0  9.606786e-01  0.131799           0.304462  9.017162e-01
# 1  2.247043e-13  0.000000           0.000000  1.244277e-21
#
# [2 rows x 24 columns]

# %% [markdown]
# #### importantly, no columns appear to be normally distributed using either normality test

# %%
sns.histplot(df_features['pulseox'], bins = 20)
# Out:
# <AxesSubplot:xlabel='pulseox', ylabel='Count'>

# %% [markdown]
# #### Remove outliers by removing all values with a zscore +/- 4

# %%
summary_stats = df_continuous.describe()

# %%
summary_stats
# Out:
#        time_on_vent  anchor_age     spontrr   heartrate  std_spontrr  \
# count    757.000000  757.000000  757.000000  757.000000   757.000000
# mean     109.646499   67.856011   19.347424   83.896962     4.417931
# std      146.665574   11.156493    5.687024   17.216946     2.522956
# min        6.033333   36.000000    0.000000    0.000000     0.000000
# 25%       24.383333   60.000000   15.000000   72.000000     2.604940
# 50%       60.550000   68.000000   19.000000   83.000000     3.848314
# 75%      132.583333   76.000000   23.000000   94.000000     5.767830
# max     1252.066667   91.000000   38.000000  147.000000    15.744992
#
#            weight      sodium        abg_po2         abg_ph        hco3  ...  \
# count  757.000000  757.000000     757.000000     757.000000  757.000000  ...
# mean   185.378864  139.964333    1433.438573    1328.386764   26.606341  ...
# std     58.801153    4.887360   36341.532397   36345.313128    5.573070  ...
# min     71.900000  125.000000      25.000000       7.140000   12.000000  ...
# 25%    143.000000  136.000000      83.000000       7.350000   22.000000  ...
# 50%    176.000000  140.000000     100.000000       7.400000   26.000000  ...
# 75%    220.000000  143.000000     127.000000       7.440000   30.000000  ...
# max    509.300000  156.000000  999999.000000  999999.000000   46.000000  ...
#
#        creatinine         bun      height    lactic_acid  hemoglobin  \
# count  757.000000  757.000000  757.000000     757.000000  757.000000
# mean     1.430383   32.092470   66.122123    1322.359049    9.775165
# std      1.239037   23.012175    4.141717   36345.532503    1.867075
# min      0.200000    3.000000   53.074803       0.500000    6.500000
# 25%      0.700000   16.000000   62.996063       1.000000    8.300000
# 50%      1.000000   25.000000   66.070866       1.200000    9.400000
# 75%      1.600000   42.000000   68.948819       1.600000   10.900000
# max      9.400000  134.000000   78.770079  999999.000000   16.400000
#
#               wbg  tidalvolume        temp  std_bloodpressure     pulseox
# count  757.000000   757.000000  757.000000         757.000000  757.000000
# mean    12.044386   461.579621   36.955923           9.620830   97.100396
# std      5.566549   146.930846    2.059632          13.989352    2.668742
# min      0.300000   101.000000  -17.777778           0.547723   86.000000
# 25%      7.900000   357.000000   36.722222           5.162804   95.000000
# 50%     11.200000   442.000000   37.000000           7.286975   98.000000
# 75%     14.700000   541.000000   37.277778          10.618380  100.000000
# max     43.700000  1102.000000   39.611111         296.433466  100.000000
#
# [8 rows x 24 columns]

# %%
df_continuous
# Out:
#      time_on_vent  anchor_age  spontrr  heartrate  std_spontrr  weight  \
# 0      168.400000          60     22.0      124.0     8.140434   140.1
# 1       77.400000          77     20.0       96.0     5.348936   132.0
# 2       49.250000          73     27.0       89.0     5.253570   154.0
# 3       13.333333          38     16.0       86.0     6.244998   162.8
# 4       97.300000          60     33.0      104.0     3.900142   158.4
# ..            ...         ...      ...        ...          ...     ...
# 752     84.916667          66     18.0       71.0     3.076795   274.8
# 753     26.000000          62     16.0      101.0     5.970164   221.1
# 754    125.016667          77     15.0       88.0     5.724418   152.2
# 755    281.300000          69     17.0       87.0     2.675857   149.8
# 756     84.700000          71     24.0       84.0     2.282224   268.4
#
#      sodium  abg_po2  abg_ph  hco3  ...  creatinine   bun     height  \
# 0     133.0     70.0    7.46  28.0  ...         0.7  30.0  72.917323
# 1     149.0    129.0    7.40  29.0  ...         1.6  34.0  66.964567
# 2     134.0     98.0    7.35  23.0  ...         0.8  37.0  70.039370
# 3     141.0     75.0    7.29  22.0  ...         0.6   6.0  64.980315
# 4     141.0     80.0    7.42  22.0  ...         1.0  24.0  61.905512
# ..      ...      ...     ...   ...  ...         ...   ...        ...
# 752   150.0     72.0    7.37  37.0  ...         1.7  75.0  66.964567
# 753   133.0    117.0    7.32  20.0  ...         1.5  60.0  74.007874
# 754   144.0    216.0    7.26  29.0  ...         1.4  54.0  59.921260
# 755   144.0     69.0    7.35  38.0  ...         0.6  32.0  66.070866
# 756   144.0     89.0    7.35  21.0  ...         1.6  11.0  64.086614
#
#      lactic_acid  hemoglobin   wbg  tidalvolume       temp  std_bloodpressure  \
# 0            1.6         8.9   5.9        461.0  36.444444          18.906789
# 1            1.5         9.7  11.2        465.0  37.111111          12.537942
# 2            2.0        10.8   0.6        533.0  35.666667          13.377308
# 3            0.7        10.8  20.3        474.0  36.666667          14.729891
# 4            1.5        10.5  17.3        387.0  38.222222           3.386247
# ..           ...         ...   ...          ...        ...                ...
# 752          1.7         9.4   8.5        407.0  36.888889           5.913262
# 753          1.7         7.7  26.4        552.0  36.944444           2.422120
# 754          1.1         8.1  15.2        357.0  38.888889           6.534524
# 755          0.5         7.6   9.9        764.0  37.000000           4.956477
# 756          0.8         7.1  15.0        475.0  37.166667           9.373633
#
#      pulseox
# 0       98.0
# 1       97.0
# 2       99.0
# 3       95.0
# 4       97.0
# ..       ...
# 752    100.0
# 753     96.0
# 754     99.0
# 755    100.0
# 756    100.0
#
# [757 rows x 24 columns]

# %%
cols = list(df_continuous.columns)
df_new = df_continuous.copy()
for col in cols:
    df_new[col] = (df_continuous[col]-df_continuous[col].mean())/df_continuous[col].std()

# %%
for col in cols:
    df_continuous[col] = np.where(((df_continuous[col]-df_continuous[col].mean())/df_continuous[col].std()>4)|
                                  ((df_continuous[col]-df_continuous[col].mean())/df_continuous[col].std()<-4),
                                  np.NaN,df_continuous[col])

# %%
df_continuous.isnull().sum()
# Out:
# time_on_vent         11
# anchor_age            0
# spontrr               0
# heartrate             2
# std_spontrr           2
# weight                3
# sodium                0
# abg_po2               1
# abg_ph                1
# hco3                  0
# abg_pco2              1
# bloodpressure         2
# std_pulseox           1
# std_heartrate         6
# creatinine            8
# bun                   3
# height                0
# lactic_acid           1
# hemoglobin            0
# wbg                   2
# tidalvolume           1
# temp                  1
# std_bloodpressure     8
# pulseox               1
# dtype: int64

# %%
df_continuous['tidal_weight'] = df_continuous['tidalvolume']/ df_continuous['weight']

# %%
# weight in lb x 703/ height in inches2
df_continuous['bmi'] = (df_continuous['weight']*703)/ df_continuous['height']**2

# %%
df_continuous
# Out:
#      time_on_vent  anchor_age  spontrr  heartrate  std_spontrr  weight  \
# 0      168.400000        60.0     22.0      124.0     8.140434   140.1
# 1       77.400000        77.0     20.0       96.0     5.348936   132.0
# 2       49.250000        73.0     27.0       89.0     5.253570   154.0
# 3       13.333333        38.0     16.0       86.0     6.244998   162.8
# 4       97.300000        60.0     33.0      104.0     3.900142   158.4
# ..            ...         ...      ...        ...          ...     ...
# 752     84.916667        66.0     18.0       71.0     3.076795   274.8
# 753     26.000000        62.0     16.0      101.0     5.970164   221.1
# 754    125.016667        77.0     15.0       88.0     5.724418   152.2
# 755    281.300000        69.0     17.0       87.0     2.675857   149.8
# 756     84.700000        71.0     24.0       84.0     2.282224   268.4
#
#      sodium  abg_po2  abg_ph  hco3  ...     height  lactic_acid  hemoglobin  \
# 0     133.0     70.0    7.46  28.0  ...  72.917323          1.6         8.9
# 1     149.0    129.0    7.40  29.0  ...  66.964567          1.5         9.7
# 2     134.0     98.0    7.35  23.0  ...  70.039370          2.0        10.8
# 3     141.0     75.0    7.29  22.0  ...  64.980315          0.7        10.8
# 4     141.0     80.0    7.42  22.0  ...  61.905512          1.5        10.5
# ..      ...      ...     ...   ...  ...        ...          ...         ...
# 752   150.0     72.0    7.37  37.0  ...  66.964567          1.7         9.4
# 753   133.0    117.0    7.32  20.0  ...  74.007874          1.7         7.7
# 754   144.0    216.0    7.26  29.0  ...  59.921260          1.1         8.1
# 755   144.0     69.0    7.35  38.0  ...  66.070866          0.5         7.6
# 756   144.0     89.0    7.35  21.0  ...  64.086614          0.8         7.1
#
#       wbg  tidalvolume       temp  std_bloodpressure  pulseox  tidal_weight  \
# 0     5.9        461.0  36.444444          18.906789     98.0      3.290507
# 1    11.2        465.0  37.111111          12.537942     97.0      3.522727
# 2     0.6        533.0  35.666667          13.377308     99.0      3.461039
# 3    20.3        474.0  36.666667          14.729891     95.0      2.911548
# 4    17.3        387.0  38.222222           3.386247     97.0      2.443182
# ..    ...          ...        ...                ...      ...           ...
# 752   8.5        407.0  36.888889           5.913262    100.0      1.481077
# 753  26.4        552.0  36.944444           2.422120     96.0      2.496608
# 754  15.2        357.0  38.888889           6.534524     99.0      2.345598
# 755   9.9        764.0  37.000000           4.956477    100.0      5.100134
# 756  15.0        475.0  37.166667           9.373633    100.0      1.769747
#
#            bmi
# 0    18.523883
# 1    20.693747
# 2    22.069454
# 3    27.104793
# 4    29.057073
# ..         ...
# 752  43.080618
# 753  28.378420
# 754  29.799440
# 755  24.123879
# 756  45.941290
#
# [757 rows x 26 columns]

# %%
df_continuous.dropna(inplace=True)

# %%
df_continuous.apply(normaltest)
# Out:
#    time_on_vent  anchor_age    spontrr     heartrate   std_spontrr  \
# 0  3.580693e+02    9.778963  14.433228  2.944341e+01  1.120864e+02
# 1  1.762947e-78    0.007525   0.000734  4.040590e-07  4.578812e-25
#
#          weight    sodium        abg_po2        abg_ph       hco3  ...  \
# 0  7.966964e+01  2.477261   5.949546e+02  2.840140e+01  17.671884  ...
# 1  5.011382e-18  0.289781  6.415647e-130  6.803234e-07   0.000145  ...
#
#      height   lactic_acid    hemoglobin           wbg   tidalvolume  \
# 0  8.712761  1.821360e+02  5.846955e+01  9.084203e+01  7.030365e+01
# 1  0.012825  2.816267e-40  2.011405e-13  1.878896e-20  5.416964e-16
#
#            temp  std_bloodpressure       pulseox  tidal_weight           bmi
# 0  7.853722e+01       5.191820e+02  4.941575e+01  1.978829e+02  6.327893e+01
# 1  8.827921e-18      1.824172e-113  1.859971e-11  1.072170e-43  1.816165e-14
#
# [2 rows x 26 columns]

# %%
df_continuous.apply(shapiro)
# Out:
#    time_on_vent  anchor_age   spontrr     heartrate   std_spontrr  \
# 0  7.413417e-01    0.991434  0.987370  9.845331e-01  9.294053e-01
# 1  8.790821e-32    0.000398  0.000008  8.062052e-07  9.248411e-18
#
#          weight    sodium       abg_po2    abg_ph      hco3  ...    height  \
# 0  9.603975e-01  0.993940  6.853883e-01  0.985502  0.985696  ...  0.986453
# 1  6.618927e-13  0.006042  2.843840e-34  0.000002  0.000002  ...  0.000004
#
#     lactic_acid    hemoglobin           wbg   tidalvolume          temp  \
# 0  9.049419e-01  9.568935e-01  9.517177e-01  9.624594e-01  9.427753e-01
# 1  1.363918e-20  1.452268e-13  1.788138e-14  1.686056e-12  6.729306e-16
#
#    std_bloodpressure       pulseox  tidal_weight           bmi
# 0       7.909586e-01  9.074498e-01  9.220614e-01  9.594463e-01
# 1       3.469784e-29  2.503066e-20  1.120593e-18  4.347219e-13
#
# [2 rows x 26 columns]

# %%
df_categorical = df_features.copy()
df_categorical = df_features[['re_intub_class','gender','admission_type']]

# %%
from scipy.stats import boxcox

# %%
df_tobox = df_continuous.copy()

# %%
df_tobox.drop('pulseox',axis=1,inplace=True)

# %%
from sklearn.preprocessing import quantile_transform

# %%
df_tobox = df_tobox.transform(lambda x: boxcox((x + 1),0))

# %%
pulseox = df_continuous['pulseox'].values
df_tobox['pulseox'] = quantile_transform(pulseox.reshape(-1,1),
                             n_quantiles=300,
                             output_distribution='normal',
                             copy=True)

# %%
df_model = pd.merge(left = df_tobox, right=df_categorical, how = 'inner',left_index = True, right_index = True)

# %%
#df_model = pd.concat([df_to_model,df_continuous['pulseox']],axis=1)

# %%
df_model
# Out:
#      time_on_vent  anchor_age   spontrr  heartrate  std_spontrr    weight  \
# 0        5.132263    4.110874  3.135494   4.828314     2.212708  4.949469
# 1        4.361824    4.356709  3.044522   4.574711     1.848287  4.890349
# 2        3.917011    4.304065  3.332205   4.499810     1.833153  5.043425
# 3        2.662588    3.663562  2.833213   4.465908     1.980311  5.098646
# 4        4.588024    4.110874  3.526361   4.653960     1.589264  5.071417
# ..            ...         ...       ...        ...          ...       ...
# 752      4.453378    4.204693  2.944439   4.276666     1.405311  5.619676
# 753      3.295837    4.143135  2.833213   4.624973     1.941639  5.403128
# 754      4.836414    4.356709  2.772589   4.488636     1.905745  5.031744
# 755      5.642970    4.248495  2.890372   4.477337     1.301786  5.015954
# 756      4.450853    4.276666  3.218876   4.442651     1.188521  5.596197
#
#        sodium   abg_po2    abg_ph      hco3  ...       wbg  tidalvolume  \
# 0    4.897840  4.262680  2.135349  3.367296  ...  1.931521     6.135565
# 1    5.010635  4.867534  2.128232  3.401197  ...  2.501436     6.144186
# 2    4.905275  4.595120  2.122262  3.178054  ...  0.470004     6.280396
# 3    4.955827  4.330733  2.115050  3.135494  ...  3.058707     6.163315
# 4    4.955827  4.394449  2.130610  3.135494  ...  2.906901     5.961005
# ..        ...       ...       ...       ...  ...       ...          ...
# 752  5.017280  4.290459  2.124654  3.637586  ...  2.251292     6.011267
# 753  4.897840  4.770685  2.118662  3.044522  ...  3.310543     6.315358
# 754  4.976734  5.379897  2.111425  3.401197  ...  2.785011     5.880533
# 755  4.976734  4.248495  2.122262  3.663562  ...  2.388763     6.639876
# 756  4.976734  4.499810  2.122262  3.091042  ...  2.772589     6.165418
#
#          temp  std_bloodpressure  tidal_weight       bmi   pulseox  \
# 0    3.622858           2.991061      1.456405  2.971638  0.155719
# 1    3.640506           2.605496      1.509115  3.077024 -0.143003
# 2    3.601868           2.665651      1.495382  3.138509  0.469383
# 3    3.628776           2.755563      1.363933  3.335940 -0.764086
# 4    3.669243           1.478474      1.236396  3.403098 -0.143003
# ..        ...                ...           ...       ...       ...
# 752  3.634658           1.933442      0.908693  3.786020  5.199338
# 753  3.636123           1.230260      1.251793  3.380260 -0.436868
# 754  3.686098           2.019496      1.207645  3.427497  0.469383
# 755  3.637586           1.784479      1.808311  3.223819  5.199338
# 756  3.641963           2.339267      1.018756  3.848898  5.199338
#
#      re_intub_class  gender     admission_type
# 0                 0       M           EW EMER.
# 1                 0       F           EW EMER.
# 2                 1       M             URGENT
# 3                 0       F           EW EMER.
# 4                 0       F             URGENT
# ..              ...     ...                ...
# 752               0       M           EW EMER.
# 753               0       M           EW EMER.
# 754               0       F             URGENT
# 755               0       M             URGENT
# 756               0       F  OBSERVATION ADMIT
#
# [709 rows x 29 columns]

# %%
#df_to_model['testing'],lmbda= boxcox((df_to_model['pulseox']+1))

# %%
sns.histplot(df_model, x = 'pulseox', hue = 're_intub_class', bins = 10)
# Out:
# <AxesSubplot:xlabel='pulseox', ylabel='Count'>

# %%
df_model.columns
# Out:
# Index(['time_on_vent', 'anchor_age', 'spontrr', 'heartrate', 'std_spontrr',
#        'weight', 'sodium', 'abg_po2', 'abg_ph', 'hco3', 'abg_pco2',
#        'bloodpressure', 'std_pulseox', 'std_heartrate', 'creatinine', 'bun',
#        'height', 'lactic_acid', 'hemoglobin', 'wbg', 'tidalvolume', 'temp',
#        'std_bloodpressure', 'tidal_weight', 'bmi', 'pulseox', 're_intub_class',
#        'gender', 'admission_type'],
#       dtype='object')

# %%
#df_to_model['newpulse'] = df_to_model['pulseox']

# %%
#df_to_model.reset_index(inplace=True)
#df_to_model.drop('index',axis=1,inplace=True)

# %%
plt.figure(figsize = (30,10))
sns.heatmap(df_model.corr())
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
#df_to_model.drop(['tidalvolume','weight'],axis=1,inplace=True)

# %%
df_model.describe()
# Out:
#        time_on_vent  anchor_age     spontrr   heartrate  std_spontrr  \
# count    709.000000  709.000000  709.000000  709.000000   709.000000
# mean       4.054807    4.218739    2.971752    4.424833     1.582758
# std        1.052246    0.170169    0.303659    0.194540     0.444398
# min        1.950661    3.610918    0.000000    3.784190     0.000000
# 25%        3.220208    4.110874    2.772589    4.290459     1.270738
# 50%        4.101817    4.234107    2.995732    4.430817     1.573583
# 75%        4.836414    4.343805    3.178054    4.553877     1.908122
# max        6.524761    4.521789    3.663562    4.997212     2.695861
#
#            weight      sodium     abg_po2      abg_ph        hco3  ...  \
# count  709.000000  709.000000  709.000000  709.000000  709.000000  ...
# mean     5.175190    4.947979    4.656382    2.127546    3.299695  ...
# std      0.293791    0.034382    0.372203    0.008025    0.204712  ...
# min      4.289089    4.836282    3.258097    2.096790    2.564949  ...
# 25%      4.967032    4.919981    4.430817    2.122262    3.135494  ...
# 50%      5.176150    4.948760    4.615121    2.128232    3.295837  ...
# 75%      5.383118    4.969813    4.852030    2.132982    3.433987  ...
# max      6.037871    5.056246    6.388561    2.151762    3.850148  ...
#
#        lactic_acid  hemoglobin         wbg  tidalvolume        temp  \
# count   709.000000  709.000000  709.000000   709.000000  709.000000
# mean      0.835613    2.364314    2.478463     6.085278    3.638448
# std       0.214902    0.168746    0.436552     0.318405    0.013790
# min       0.405465    2.014903    0.262364     4.624973    3.558518
# 25%       0.693147    2.230014    2.186051     5.877736    3.630249
# 50%       0.788457    2.341806    2.501436     6.091310    3.637586
# 75%       0.955511    2.484907    2.766319     6.297109    3.644870
# max       1.686399    2.856470    3.523415     6.905753    3.704042
#
#        std_bloodpressure  tidal_weight         bmi     pulseox  re_intub_class
# count         709.000000    709.000000  709.000000  709.000000      709.000000
# mean            2.118392      1.267879    3.381728    1.003389        0.100141
# std             0.487457      0.285790    0.269405    2.540435        0.300400
# min             0.436785      0.333250    2.713238   -5.199338        0.000000
# 25%             1.806664      1.086500    3.192540   -0.764086        0.000000
# 50%             2.107493      1.265958    3.379731   -0.143003        0.000000
# 75%             2.417050      1.451313    3.569239    5.199338        0.000000
# max             4.154136      2.248111    4.107496    5.199338        1.000000
#
# [8 rows x 27 columns]

# %%
#df_continuous.reset_index(inplace=True)
#df_continuous.drop('index',axis=1,inplace=True)

# %%
df_model.reset_index(inplace=True)
df_model.drop('index',axis=1,inplace=True)

# %%
df_model.to_feather('../data/processed/df_to_model_copd')
